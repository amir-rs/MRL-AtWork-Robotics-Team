# %%
# based on https://www.tensorflow.org/hub/tutorials/tf2_image_retraining

# %%
from tensorflow.keras.applications import EfficientNetB0
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import tensorflow_hub as hub

import os
import sys

tf.__version__
# Out:
# 2023-04-14 15:24:00.222508: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# '2.12.0'

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)

# %%
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# GPU is available

# %%
batch_size = 64
image_size = 224

model_name = "efficientnetv2-b0-21k"
model_handle = "https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b0/classification/2"

print(f"Selected model: {model_name} : {model_handle}")

pixels = 224
IMAGE_SIZE = (pixels, pixels)
print(f"Input size {IMAGE_SIZE}")
# Out:
# Selected model: efficientnetv2-b0-21k : https://tfhub.dev/google/imagenet/efficientnet_v2_imagenet21k_b0/classification/2
# Input size (224, 224)

# %%
data_dir = "/tf/dataset/cavity_images"

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    shuffle=True,
    validation_split=0.2,
    subset="training",
    label_mode='categorical',
    seed=123,
    image_size=(image_size, image_size),
    batch_size=batch_size,
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    shuffle=True,
    validation_split=0.2,
    subset="validation",
    label_mode='categorical',
    seed=123,
    image_size=(image_size, image_size),
    batch_size=batch_size,
)
class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
# Out:
# Found 20067 files belonging to 10 classes.
# Using 16054 files for training.
# 2023-04-14 15:24:09.030798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 15:24:09.031039: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 15:24:09.031179: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 15:24:09.561401: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 15:24:09.561578: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 15:24:09.561701: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-14 15:24:09.562139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4555 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti, pci bus id: 0000:01:00.0, compute capability: 7.5
# Found 20067 files belonging to 10 classes.
# Using 4013 files for validation.

# %%
do_fine_tuning = True

print("Building model with", model_handle)
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    hub.KerasLayer(model_handle, trainable=do_fine_tuning),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(len(class_names),
                          kernel_regularizer=tf.keras.regularizers.l2(0.0001))
])
model.build()
model.summary()

# %%
model.summary()
(None,)+IMAGE_SIZE+(3,)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 21843)             33900195
#
#  dropout (Dropout)           (None, 21843)             0
#
#  dense (Dense)               (None, 10)                218440
#
# =================================================================
# Total params: 34,118,635
# Trainable params: 34,058,027
# Non-trainable params: 60,608
# _________________________________________________________________
# (None, 224, 224, 3)

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2), 
  loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
steps_per_epoch = len(train_ds) // batch_size
validation_steps = len(test_ds) // batch_size

hist = model.fit(
    train_ds,
    epochs=5, steps_per_epoch=steps_per_epoch,
    validation_data=test_ds
    )
# Out:
# Epoch 1/5
# 2023-04-14 15:24:24.287353: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [16054]
# 	 [[{{node Placeholder/_0}}]]
# 2023-04-14 15:24:24.287649: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [16054]
# 	 [[{{node Placeholder/_0}}]]
# 2023-04-14 15:24:24.658876: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/head/StatefulPartitionedCall_grad/head/StatefulPartitionedCall' with dtype float and shape [?,1280]
# 	 [[{{node gradients/head/StatefulPartitionedCall_grad/head/StatefulPartitionedCall}}]]
# 2023-04-14 15:24:24.658955: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/head/StatefulPartitionedCall_grad/head/StatefulPartitionedCall
I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/blocks_16/StatefulPartitionedCall_grad/blocks_16/StatefulPartitionedCall_35' with dtype float and shape [?,?,?,1152]
# 	 [[{{node gradients/blocks_16/StatefulPartitionedCall_grad/blocks_16/StatefulPartitionedCall_35}}]]
# 2023-04-14 15:24:25.207466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/blocks_15/StatefulPartitionedCall_grad/blocks_15/StatefulPartitionedCall' with dtype float and shape [?,?,?,192]
# 	 [[{{node gradients/blocks_15/StatefulPartitionedCall_grad/blocks_15/StatefulPartitionedCall}}]]
# 2023-04-14 15:24:25.207550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/blocks_15/StatefulPartitionedCall_grad/blocks_15/StatefulPartitionedCall_1' with dtype float and shape [?,?,?,192]
# 	 [[{{node gradients/blocks_15/StatefulPartitionedCall_grad/blocks_15/StatefulPartitionedCall_1}}]]
# 2023-04-14 15:24:25.207594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/blocks_15/StatefulPartitionedCall_grad/blocks_15/StatefulPartitionedCall_2' with dtype float and shape [?,?,?,192]
# 	 [[{{node gradients/blocks_15/StatefulPartitionedCall_grad/blocks_15/StatefulPartitionedCall_2}}]]
# ...
# 2023-04-14 15:24:50.626389: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fe77b00 of size 512 next 21
# 2023-04-14 15:24:50.626402: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fe77d00 of size 301056 next 22
# 2023-04-14 15:24:50.626415: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fec1500 of size 2816 next 23
# 2023-04-14 15:24:50.626428: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fec2000 of size 2816 next 24
# 2023-04-14 15:24:50.626440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fec2b00 of size 24320 next 25
# 2023-04-14 15:24:50.626453: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fec8a00 of size 2816 next 26
# 2023-04-14 15:24:50.626466: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fec9500 of size 512 next 27
# 2023-04-14 15:24:50.626479: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fec9700 of size 2816 next 28
# 2023-04-14 15:24:50.626492: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0feca200 of size 75264 next 29
# 2023-04-14 15:24:50.626506: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fedc800 of size 256 next 30
# 2023-04-14 15:24:50.626520: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0fedc900 of size 75264 next 31
# 2023-04-14 15:24:50.626534: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0feeef00 of size 2816 next 32
# 2023-04-14 15:24:50.626547: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0feefa00 of size 301056 next 33
# 2023-04-14 15:24:50.626559: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff39200 of size 512 next 34
# 2023-04-14 15:24:50.626571: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff39400 of size 512 next 35
# 2023-04-14 15:24:50.626583: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff39600 of size 301056 next 36
# 2023-04-14 15:24:50.626596: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff82e00 of size 2816 next 37
# 2023-04-14 15:24:50.626609: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff83900 of size 16384 next 38
# 2023-04-14 15:24:50.626622: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff87900 of size 2816 next 39
# 2023-04-14 15:24:50.626634: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff88400 of size 24320 next 40
# 2023-04-14 15:24:50.626647: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff8e300 of size 2816 next 41
# 2023-04-14 15:24:50.626661: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff8ee00 of size 2816 next 42
# 2023-04-14 15:24:50.626672: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ff8f900 of size 75264 next 43
# 2023-04-14 15:24:50.626685: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ffa1f00 of size 256 next 44
# 2023-04-14 15:24:50.626699: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ffa2000 of size 75264 next 45
# 2023-04-14 15:24:50.626712: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ffb4600 of size 2816 next 46
# 2023-04-14 15:24:50.626726: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7fcd0ffb5100 of size 306944 next 18446744073709551615
# 2023-04-14 15:24:50.626738: I tensorflow/tsl/framework/bfc_allocator.cc:1100]      Summary of in-use Chunks by size:
# 2023-04-14 15:24:50.626760: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 200 Chunks of size 256 totalling 50.0KiB
# 2023-04-14 15:24:50.626776: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 100 Chunks of size 512 totalling 50.0KiB
# 2023-04-14 15:24:50.626789: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 100 Chunks of size 768 totalling 75.0KiB
# 2023-04-14 15:24:50.626800: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 1024 totalling 2.0KiB
# 2023-04-14 15:24:50.626811: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-04-14 15:24:50.626825: I tensorflow/tsl/framework/bfc_allocator.cc:1103]
I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 983040 totalling 2.81MiB
# 2023-04-14 15:24:50.627489: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 2408448 totalling 6.89MiB
# 2023-04-14 15:24:50.627501: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4358400 totalling 4.16MiB
# 2023-04-14 15:24:50.627513: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 4816896 totalling 18.38MiB
# 2023-04-14 15:24:50.627528: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 5619712 totalling 53.59MiB
# 2023-04-14 15:24:50.627539: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 8429568 totalling 40.20MiB
# 2023-04-14 15:24:50.627548: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 9294336 totalling 8.86MiB
# 2023-04-14 15:24:50.627559: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 9575424 totalling 9.13MiB
# 2023-04-14 15:24:50.627572: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 9 Chunks of size 9633792 totalling 82.69MiB
# 2023-04-14 15:24:50.627585: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 13 Chunks of size 14450688 totalling 179.16MiB
# 2023-04-14 15:24:50.627596: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 18658304 totalling 17.79MiB
# 2023-04-14 15:24:50.627610: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 18 Chunks of size 19267584 totalling 330.75MiB
# 2023-04-14 15:24:50.627625: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 25690112 totalling 171.50MiB
# 2023-04-14 15:24:50.627640: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 9 Chunks of size 28901376 totalling 248.06MiB
# 2023-04-14 15:24:50.627654: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 39 Chunks of size 33718272 totalling 1.22GiB
# 2023-04-14 15:24:50.627670: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 38532864 totalling 36.75MiB
# 2023-04-14 15:24:50.627686: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 8 Chunks of size 38535168 totalling 294.00MiB
# 2023-04-14 15:24:50.627701: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 38962944 totalling 37.16MiB
# 2023-04-14 15:24:50.627718: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 51380224 totalling 343.00MiB
# 2023-04-14 15:24:50.627731: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 61681152 totalling 58.82MiB
# 2023-04-14 15:24:50.627744: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 65400832 totalling 62.37MiB
# 2023-04-14 15:24:50.627758: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 102760448 totalling 686.00MiB
# 2023-04-14 15:24:50.627773: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 111836160 totalling 106.66MiB
# 2023-04-14 15:24:50.627787: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 134217728 totalling 128.00MiB
# 2023-04-14 15:24:50.627801: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 151516160 totalling 144.50MiB
# 2023-04-14 15:24:50.627815: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 156599296 totalling 149.34MiB
# 2023-04-14 15:24:50.627829: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 4.44GiB
# 2023-04-14 15:24:50.627844: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 4776460288 memory_limit_: 4776460288 available bytes: 0 curr_region_allocation_bytes_: 8589934592
# 2023-04-14 15:24:50.627861: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                      4776460288
# InUse:                      4767161600
# MaxInUse:                   4776456448
# NumAllocs:                        2016
# MaxAllocSize:               1005584384
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-04-14 15:24:50.627922: W tensorflow/tsl/framework/bfc_allocator.cc:497] ****************************************************************************************************
# 2023-04-14 15:24:50.627956: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at fused_batch_norm_op.cc:1563 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[64,1152,7,7] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2023-04-14 15:24:50.627992: I tensorflow/core/common_runtime/executor.cc:1197] [/job:localhost/replica:0/task:0/device:GPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[64,1152,7,7] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node tpu_batch_normalization_1/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[11], line 4
#       1 steps_per_epoch = len(train_ds) // batch_size
#       2 validation_steps = len(test_ds) // batch_size
# ----> 4 hist = model.fit(
#       5     train_ds,
#       6     epochs=5, steps_per_epoch=steps_per_epoch,
#       7     validation_data=test_ds
#       8     )
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# OOM when allocating tensor with shape[64,1152,7,7] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node tpu_batch_normalization_1/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_57082]

# %%
def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()
